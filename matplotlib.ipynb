# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhil2008github/Data-ops/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
x = [1,2,3,4,5,6,7,8,9]
y = [33,76,54,23,62,75,45,85,78]

# %%
plt.plot(x,y,color ='green') # colour = used to change the color

# %%
 plt.plot(x,y,color ='green', linewidth = 5)  # line =width is used to increasde the width of line

# %%
 plt.plot(x,y,color ='green', linewidth = 5, linestyle = "dotted") #linestyle is used to change the style of line

# %%
plt.xlabel ('day')
plt.ylabel('wind speed')
plt.title('Weather')
plt.plot(x,y,color ='green', linewidth = 5, linestyle = "dotted")

# %%
plt.plot(x,y, 'r- .-')

# %%
plt.plot(x,y, 'r-D' ,markersize=20) # marker size is incerase the size of points

# %%
plt.plot(x,y, 'r-D' ,markersize=20, alpha =.5) # alpha is to define the transparency of the line
